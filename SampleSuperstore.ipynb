# %% [markdown]
# <a href="https://colab.research.google.com/github/lotaa/The-Sparks-Foundation-Task-3/blob/main/SampleSuperstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Author : Omnia Hosny**

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
# # Super Store
# Explantory Data Analysis on dataset 'sampleSuperstore'
#
#
# **The goal of notebook.**
# * what all business problems you can derive by exploring the data?

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Reading data from remote link
url = "/content/SampleSuperstore.csv"
data = pd.read_csv(url)
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Shape of data
data.shape
# Out:
# (9994, 13)

# %%
#information About the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Summary Statistic
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# I show that mimimum of profit is negative this is impossible

# %%
# Check the nulls Values
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#no. of duplicated rows
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# 17 duplicated values are present which is 0.17% of data. So, it can be deleted.

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
data['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
plt.hist(data['Profit'],bins=5)
plt.title("The Distribution of Profit of store")
# Out:
# Text(0.5, 1.0, 'The Distribution of Profit of store')

# %% [markdown]
# This show that The profit has extreme values (the histogram is leptokurtic)

# %%
data.hist(bins=50, figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb6fbb17990>,
# ...
#       dtype=object)

# %%
sns.barplot(x='Profit', y='Category',data=data, alpha=0.5)
plt.title("Relation between the Category and Profit")
# Out:
# Text(0.5, 1.0, 'Relation between the Category and Profit')

# %% [markdown]
# AS we show the Category of technology Is Most profitable Category.

# %% [markdown]
# **Now There are two Questions**
#
# 1.   Why the category of Technology is The Most profit?
# 2.   Why the others categories do not achieve profit more?

# %%
#first I check if the sold quatity of all categories are the same
sns.barplot(x='Category', y='Quantity',data=data, color='y', alpha=0.3)
plt.title('The Quantity Of Each Category')
# Out:
# Text(0.5, 1.0, 'The Quantity Of Each Category')

# %% [markdown]
# We Show that all The same

# %% [markdown]
# What is the Relation between Quantity and category of technology?

# %%
# second I Check that the quantity affects the profit
sns.relplot(x='Quantity', y='Profit', data=data, kind="line", color='r')
plt.title("The Relationship between Quantity and Profit")
# Out:
# Text(0.5, 1.0, 'The Relationship between Quantity and Profit')

# %%
sns.scatterplot(x='Quantity', y='Profit', data=data)

# %% [markdown]
# AS show there is relation between Quantity and Profit

# %%
#third I check the Profit of each sub-Category of Technology
Tech=data[data['Category'] == 'Technology']
sub_category_Tech=Tech['Sub-Category']
sns.barplot(x=data['Profit'], y=sub_category_Tech)

# %% [markdown]
# As we show the Copiers are most profit of category of Tech, and The lowes sub category is Machines this has a negative Profit

# %% [markdown]
# **Q:    What is the most category sales?**

# %%
sns.barplot(x='Sales', y='Category', data=data, color='r', alpha=0.4)
plt.title('Sales of Each Category')
# Out:
# Text(0.5, 1.0, 'Sales of Each Category')

# %% [markdown]
# Technology has the biggest sales of all Categories
#
# Although furniture has a last second-place of sales it is less profit

# %% [markdown]
# **Q:           What is the ship mode has most profit?**

# %%
sns.barplot(x='Ship Mode', y='Profit', data=data, color='y', alpha=0.6)
plt.title('Relation Between The Profit And The ship mode')
# Out:
# Text(0.5, 1.0, 'Relation Between The Profit And The ship mode')

# %% [markdown]
# The 'frist class' has most profit

# %% [markdown]
# **Q:              What is The Segment has most profit?**

# %%
sns.barplot(x='Segment',y='Profit', data=data)
plt.title('Profit of Each Segment')
# Out:
# Text(0.5, 1.0, 'Profit of Each Segment')

# %% [markdown]
# AS we see the bigger profit is HOME OFFICE

# %%
sns.barplot(x='Segment',y='Sales', data=data, color='b')
plt.title('Sales of Each Segment')
# Out:
# Text(0.5, 1.0, 'Sales of Each Segment')

# %%
# total Sales for each State
data_state_sales = data.groupby('State')['Sales'].sum().sort_values(ascending = False).plot.bar(figsize = (15, 5), 
                                                                                            color = 'Cornflowerblue')
plt.ylabel('Total Sales in USD$')
plt.xlabel('American States')
plt.title('Total State-Wise Sales', fontsize = 20)
plt.show()

# %%
# total Profit for each State
data_state_profit = data.groupby('State')['Profit'].sum().sort_values(ascending = False).plot.bar(figsize = (15, 5), 
                                                                                            color = 'Cornflowerblue')
plt.ylabel('Total Profit in USD$')
plt.xlabel('American States')
plt.title('Total State-Wise Sales', fontsize = 20)
plt.show()

# %% [markdown]
# From the last Two graphs We see that California ans New York is best sales and best profit , but Texas in third place in sales but it is losing the company and also Ohio

# %%
plt.boxplot(x=data["Discount"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fb6f867d8d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb6f8681910>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb6f8609950>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb6f8609410>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fb6f867de50>,
#   <matplotlib.lines.Line2D at 0x7fb6f86813d0>]}

# %% [markdown]
# The discount Has three outliers

# %%
sns.scatterplot(x='Discount', y='Sales', data=data)
plt.title('Relation Between Discount And Sales')
print("Correlation",data['Discount'].corr(data['Sales'],method='pearson', min_periods=1))
# Out:
# Correlation -0.028190124157535506

# %% [markdown]
# There is no correlation

# %%
sns.barplot(x='Region', y='Profit', data=data, color='r', alpha=0.7)
plt.title('Profit of Each Region')
# Out:
# Text(0.5, 1.0, 'Profit of Each Region')

# %%
sns.barplot(x='Region', y='Sales', data=data, color='b', alpha=0.5)
plt.title('Sales of Each Region')
# Out:
# Text(0.5, 1.0, 'Sales of Each Region')

# %% [markdown]
# South and Central has been sales well but the profit is low

# %%
sns.scatterplot(x='Sales', y='Profit', data=data)
plt.title('Relation Between Sales And Profit')
print("Correlation Between Sales and profit", data['Sales'].corr(data['Profit']))
# Out:
# Correlation Between Sales and profit 0.4790643497377062

# %%
sns.scatterplot(x='Discount', y='Quantity', data=data)
plt.title('Relation Between Discount And Quantity')
print("Correlation Between Discount and Quantity", data['Discount'].corr(data['Quantity']))
# Out:
# Correlation Between Discount and Quantity 0.008622970271156563

# %% [markdown]
# There is no correlate
